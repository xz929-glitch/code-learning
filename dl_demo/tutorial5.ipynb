# %%
# 反向传播和梯度计算
# torch有专门计算梯度的torch.autograd
import torch
# 最简单的单层
x = torch.ones(5)  # input tensor
y = torch.zeros(3)  # expected output
w = torch.randn(5, 3, requires_grad=True)#自动保存张量对loss的梯度
b = torch.randn(3, requires_grad=True)
z = torch.matmul(x, w)+b
loss = torch.nn.functional.binary_cross_entropy_with_logits(z, y)

# %%
print(f"Gradient function for z = {z.grad_fn}")
print(f"Gradient function for loss = {loss.grad_fn}")
# Out:
# Gradient function for z = <AddBackward0 object at 0x1189ebdf0>
# Gradient function for loss = <BinaryCrossEntropyWithLogitsBackward0 object at 0x1189e9f30>

# %%
loss.backward()
print(w.grad)
print(b.grad)
# Out:
# tensor([[0.0021, 0.1863, 0.0026],
#         [0.0021, 0.1863, 0.0026],
#         [0.0021, 0.1863, 0.0026],
#         [0.0021, 0.1863, 0.0026],
#         [0.0021, 0.1863, 0.0026]])
# tensor([0.0021, 0.1863, 0.0026])

# %%
z = torch.matmul(x, w)+b
print(z.requires_grad)

with torch.no_grad():
    z = torch.matmul(x, w)+b
print(z.requires_grad)
# Out:
# True
# False

# %%
z = torch.matmul(x, w)+b
z_det = z.detach()
print(z_det.requires_grad)
# Out:
# False
